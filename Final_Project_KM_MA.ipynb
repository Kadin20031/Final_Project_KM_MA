# %% [markdown]
# # Kadin McWilliams & Mason Anderson
# # Version 1
# # Fall 2023
# # Final Project

# %%
import textwrap
import shutil
import random

phone=False



def player(dialogue): #makes diaglogue easier to read in code
    print(f"{name}: "+textwrap.fill(dialogue, width=shutil.get_terminal_size().columns)+"\n")
    
def dylan(dialogue): #makes diaglogue easier to read in code
    print("Dylan: "+textwrap.fill(dialogue, width=shutil.get_terminal_size().columns)+"\n")
    
def generaldia(character,dialogue):#dialogue for side characters
    print(f"{character}: "+textwrap.fill(dialogue, width=shutil.get_terminal_size().columns)+"\n")

def narrator(dialogue): #fixes any manual coding with making sure words aren't split
    print(textwrap.fill(dialogue, width=shutil.get_terminal_size().columns)+"\n")

def optionsfunc(op1,op2): # Make reading which option is what in the code way easier
    print(f"\n1. {op1}\n2. {op2} \n\nEnter Option (1/2)")
    
def validop():#Didn't want to type this over and over so made it for the back up option
    print("\nenter a valid choice")
    
    
    
def safeEnding():#game ending goes back to beginning of the game, main()
    options=['1','2']
    choice=""
    narrator("You sit and hide in a bush until morning, you hear faint screams in the distance but you close your eyes and try not to let them bother you too much. As you see the sun gently rise over the hill you know that you can finally safely move out of the woods. You manage to make it back to your truck. You start the keys and drive solemnly back home.")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
def owlend():#game ending goes back to beginning of the game, main()
    options=['1','2']
    choice1=""
    choice2=""
    narrator("You decide to come out of the bushes and you look to your right to see two bright glowing orange eyes.")
    while choice2 not in options:
        optionsfunc("it's real","it's coming")
        choice=input()
    print("\n")
    narrator("You think that it might look like and owl but then before you can even react it is dive bombing you.")
    narrator("The owl strikes one eye and then you fall back.")
    narrator("As you are falling another owl comes and strikes your other eye.")
    narrator("You are left there to slowly bleed as you roll and screem in agony.")
    narrator("Owl Ending")
    while choice1 not in options:
        optionsfunc("Play again?","Exit Game")
        choice1=input()
        if choice1=='1':
            print("\n")
            main()
        elif choice1=='2':
            break
        else:
            validop()
    
def hiddenbush():
    options=['1','2']
    choice=""
    generaldia("???","Hello I heard someone go ahead and show yourself.")
    narrator("You are not going to be tricked any longer and continue not to show yourself.")
    generaldia("???","It was probably IT, I should get out of here before its too late for me.")
    player("(That was omnious, what did he mean by IT? Could it be the thing I heard earlier.)")
    player("(it might be better to stay in hidding and wait until morning or I should just go ahead and make a run for it?)")
    while choice not in options:
        optionsfunc("Come out and continue","Continue to hide")
        choice=input()
        if choice=='1':
            print("\n")
            owlend()
        elif choice=='2':
            print("\n")
            safeEnding()
        else:
            validop()

def firetalk():#game ending goes back to beginning of the game, main()
    options=['1','2']
    choice=""
    player("Hey can you see me I need HELP right NOW!")
    generaldia("Fire Marshall","Hey what are you doing out here this late at night?")
    player("I was hiking with my friend and we got split up I have no clue where he is.")
    generaldia("Fire Marshall","What do you mean split up? Care to elaborate anymore?")
    player("Okay fine we got in a fight and then we split up, there you go happy?")
    generaldia("Fire Marshall","No need to get so hostile with me come with me so I can atleast save you.")
    narrator("You manage to be saved by the fire marshall that was looking around in the woods. You manage to get taken back to you GMC but as the days turn into months into years Dylan is never found. While you are never formally charged all of your friends and family blame his death on you. Everyday takes a small toll on your soul and you have to live with a punishment for something you never did.")
    narrator("Fire Marshall Escape Ending")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
    
def flashlight():#Goes to firetalk() and hiddenbush()
    options=['1','2']
    choice=""
    narrator("The deeper you go on the path the more things you notice that are familiar.")
    narrator("The feeling of hope starts to bubble up within you and it helps you keep pushing.")
    narrator("As you keep walking you notice a flashlight in front of you but you cannot make out who it is")
    while choice not in options:
        optionsfunc("Approach flashlight","Hide")
        choice=input()
        if choice=='1':
            print("\n")
            firetalk()
        elif choice=='2':
            print("\n")
            hiddenbush()
        else:
            validop()
    
def infiniteEnd(): #game ending goes back to beginning of the game, main()
    options=['1','2']
    choice=""
    narrator("As you go turn after turn you start to realize that you will be walking this path forever, as you continue to do the same thing over and over you realize that there is no point to fight it anymore. After your 102 try you decide to walk straight right into the river.")
    narrator("Infitie Ending")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
    
def loop(): # goes to the infiniteEnd() 
    options=['1','2']
    j=0
    while j<6:
        choice=""
        narrator("You start walking for a while.")
        narrator("Your sense of time seems distorted.")
        narrator("You hear a family running of water, you are back where you started.")
        while choice not in options:
            optionsfunc("Left","right")
            choice=input()
            if choice =='1':
                print("\n")
                narrator("you go left")
            elif choice=='2':
                print("\n")
                narrator("you go right")
            else:
                validop()
        j+=1 
    infiniteEnd()
    

def frog(): #goes to flashlight() and loop()
    options=['1','2']
    choice=""
    narrator("As you begin to step down the left path a frog hops in front of you.")
    narrator("The frog gets on his hind legs, with his cold dead eyes stares deep into your soul and asks")
    generaldia("Frog","Are you sure that this is the right way?")
    player("(Did that frog just speak to me?)")
    while choice not in options:
        optionsfunc("I am sure","I am unsure")
        choice=input()
        if choice=='1':
            print("\n")
            player("I am sure of myself")
            narrator("Completely ignoring the frog you push onwards")
            flashlight()
        elif choice=='2':
            print("\n")
            player("I dont know the right path")
            narrator("Unsure of where to go you doubt your decision and turn around and go right.")
            loop()
        else:
            validop()
def never_found():# game ending goes to main()
    options=['1','2']
    choice=""
    player("I can't see ANYTHING WHO ARE YOU?")
    generaldia("???",f"{name} I dont why know you have left meeeeee.")
    player("Dylan is that you?")
    generaldia("Dylan?","You have come save me, help me.")
    narrator("The being let out a scream.")
    narrator("Your vision fades to complete black and you are on a singular all black plane that has no end in any direction you pick a direction and start walking.")
    narrator("Dylan manages to escape the forest, you are never found and slowly forgetten about as the time passes by.")
    narrator("Never Found Ending")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
def panicend():#game ending goes to main()
    options=['1','2']
    choice=""
    for i in range(10):
        i="help me"
        player(i)
        narrator(i)
        dylan(i)
        generaldia(i,i)
    narrator("Insanity Ending")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
        
def jumpend():#game ending goes to main()
    options=['1','2']
    choice1=""
    choice2=""
    narrator("You keep frantically running from the deer")
    generaldia("???","*IT WON'T SAVE YOU*")
    narrator("You continue to sprint until you reach the edge of a cliff.")
    narrator("Rustling and footsteps are getting louder from the bushes that are next to the cliff.")
    narrator("You walk to the cliff")
    while choice2 not in options:
        optionsfunc("Jump","Jump")
        choice2=input()
    print("\n")
    narrator("Freedom Ending")
    while choice1 not in options:
        optionsfunc("Play again?","Exit Game")
        choice1=input()
        if choice1=='1':
            print("\n")
            main()
        elif choice1=='2':
            break
        else:
            validop()
    
        
def run_to_Dylan():# goes to panicend() and jumpend()
    options=['1','2']
    choice=""
    narrator("You take off running into the woods")
    player("Dylan!!!!! DYLAN!!!!! WHERE ARE YOU?!?!?!")
    player("I AM SORRY THAT I LEFT YOU!")
    dylan(f"{name}, I am here")
    narrator("You hear what sounds like Dylan from the direction the deer was last spotted.")
    while choice not in options:
        optionsfunc("Run to voice","Keep going forward")
        choice=input()
        if choice=='1':
            print("\n")
            narrator("You run to the voice only to be meet by the deer")
            narrator("As soon as you see the deer you lock eyes")
            panicend()
        elif choice=='2':
            print("\n")
            narrator("You know not to look at the deer so you will not risk the chance of that happening")
            jumpend()
        else:
            validop()
        
    

def turnback(): # goes to run_to_Dylan() and panicend()
    options=['1','2']
    choice=""
    player("(Why is it bent that way?)")
    player("(Why is it smiling at me?)")
    narrator("Do not look into its eyes")
    while choice not in options:
        optionsfunc("Look into its eyes","Avoid eye contact")
        choice=input()
        if choice=='1':
            print("\n")
            panicend()
        elif choice=='2':
            print("\n")
            run_to_Dylan()
        else:
            validop()
    
    

            
def righthill():# goes to never_found(), turnback()
    options=['1','2']
    choice1=""
    choice2=""
    narrator("You proceed with caution and fear.")
    if phone==False:
        narrator("The trail is too to dark for you to even see where the trail is going to.")
        narrator("As you continue to stumble into darkness you bump into something.")
        never_found()
    else:
        narrator("You can barely see, only being able to make out shapes and shadows in front of you.")
        narrator("*YOU ARE NOT ALONE*")
        while choice1 not in options:
            optionsfunc("Yes","NO")
            choice1=input()
        print("\n")
        narrator("You have a strange feeling that something is watching you and you start to look around with your flashlight.")
        narrator("As you are looking around you get startled to see a deer standing there staring at you.")
        narrator("You need to ")
        narrator("You turn around to continue on your path but you have an itching feeling to turn around again.")
        while choice2 not in options:
            optionsfunc("Turn around","Keep on going")
            choice2=input()
            if choice2 =='1':
                print("\n")
                narrator("You turn around again but the deer hasn't moved? its eyes arent even illuminated by the light when you shine your flashlight at it.")
                narrator("The deer starts to creep you out so you turn around to get away from it")
                narrator("You turn around to see the deer standing right infront of you.")
                turnback()
            elif choice2=='2':
                print("\n")
                narrator("You laugh off the deer and continue to walk forward")
                narrator("all of the sudden you see what seems to be like a deer figure standing in front of you.")
                turnback()
            else:
                validop()
        
    
def lefthill():#goes to frog() and loop()
    options=['1','2']
    choice=""
    if phone==True:
        narrator("You walk down the hill hearing each step you take hyper alert of your surroundings, things start to smell like roting")
        narrator("After a short walk filled with anxiety you come up to path that has a river flowing beside it.")
        narrator("It seems that you can either go left along the river or right towards another area")
    else:
        player("Please if you will *** my skin do it slowly so I can savor the moment.")
        narrator("Help Me")
        narrator("You stumble around in the darkness down what you think is the hill.")
        narrator("If you are going to survive you better choose the correct path to take. Your time is running shorter and shorter, each decision is one step closer to insanity.")
        narrator("The path stands tall before you whispering for you to follow it, begging you to take just one more step in the correct direction.")
        narrator("Will you choose to go left or do you think right will be the correct choice?")
    while choice not in options:
        optionsfunc("Left","Right")
        choice=input()
        if choice=='1':
            print("\n")
            frog()
        elif choice=='2':
            print("\n")
            loop()
        else:
            validop()
    
def wander(): #goes to lefthill(), righthill()
    options=['1','2']
    choice=""
    narrator("You spend a couple of minutes just trying to shake off the bad nerves of what you just experienced, you push forward.")
    if phone==True:
        narrator("As your phone dimly lights the path in front of you, you are comforted by the sounds of various bugs clicking and frogs croacking.")
    else:
        narrator("As you stumble along what you think is the correct path in the dark, you are comforted by the sounds of various bugs clicking and frogs croacking.")
    narrator("Eventually you manage to reach what seems like a familiar fork in the road.")
    if phone==True:
        narrator("You shine your light to barely to able to see that right looks like it is going up hill, you remember you could get a slight signal at the top of the mountain.")
        narrator("You shine your light left and you see that the trail leads down the hill.")
    else:
        narrator("As you are slowly making your way down what you think to be a path is, you come up to a fork in the road.")
        narrator("To you right seems like it might be going up hill and left is going down hill but you cannot tell, its too dark.")
    narrator("You are presented with two options")
    while choice not in options:
        optionsfunc("Go left", "Go right")
        choice=input()
        if choice =='1':
            print("\n")
            lefthill()
        elif choice =='2':
            print("\n")
            righthill()
        else: 
            validop()

def goodending(): #ending, loops back to beginning 
    options=['1','2']
    choice=""
    narrator("As you sit and wait not knowing when this hell you entered will end you end up falling sleep leaning on a tree. You are abruptly woken up by Dylan.")
    dylan("Hey wake up man what is wrong wiht you!! Why are you just sleeping in the woods at night thats not safe lets get out of here")
    narrator("As you both link up and exit the forest together, you both then get in your car and drive home.")
    narrator("You and Dylan still remain friends but in your dreams that noise you heard still haunts you.")
    narrator("Good ending achieved")
    while choice not in options:
        optionsfunc("Play again?","Exit Game")
        choice=input()
        if choice=='1':
            print("\n")
            main()
        elif choice=='2':
            break
        else:
            validop()
def callout():#goes to wander()
    player("Hello!! DYLAN IS THAT YOU?!?!")
    player("Hello! Can anyone hear me?!")
    narrator("You hear no responses to your questions")
    player("(I could have sworen that I heard something...)")
    player("(I have been out in these woods for way too long I need to get out of here)")
    wander()
    
def alone(): #goes to callout(), goodend(), wander()
    options=['1','2']
    choice1=""
    choice2=""
    choice3=""
    choice4="" #run away or call out if 
    narrator("After leaving Dylan you begin to walk back in the direction you think you came from.")
    narrator("You have been walking for a while and now the sun has set to where everything you see is a shade of grey.")
    narrator("You now just realize that Dylan has both you your flashlights")
    if phone==True:
        narrator("Thankfully you didn't listen to Dylan and you can use your phone flashlight.")
    else:
        narrator("Walking is getting hard as you are slowly not being able to see right in front of you.")
        player("(I really wish I would have brought my phone so i'd be able to see right now)")
    narrator("As you are walking you hear something that sounds like Dylan calling out but something about it isn't quite right. There is a slight agitation to the voice.")
    generaldia("???",f"{name}, where are you?")
    if phone==True:
        narrator("The sound startles you and you jump forward put manage to dodge a tree root due to your phone flashlight.")
        narrator("Your heart is racing with adrenaline")
        while choice4 not in options:
            optionsfunc("Run away","Callout")
            choice4=input()
            if choice4 =='1':
                print("\n")
                narrator("Without wasting a second you begin to sprint away from the direction that you heard the noise.")
                narrator("You put a considerable amount of distance between you and the noise that you heard")
                wander()
            elif choice4=='2':
                print("\n")
                callout()
            else:
                validop()
    else:
        narrator("The sound startles you and you trip and fall over a tree root face first.")
        narrator("In your disoriented haze you can't remember where the sound came from.")
        while choice1 not in options:
            optionsfunc("Call out to see what is there","Sit and wait")
            choice1=input()
            if choice1=='1':
                print("\n")
                callout()
            elif choice1=='2':
                print("\n")
                narrator("You sit and wait as you hear unpolished steps approach you. Your heart starts to race as the jagged steps get closer and closer.")
                while choice2 not in options:
                    optionsfunc("Turn around?","Accept it?")
                    choice2=input()
                    if choice2=='1':
                        print("\n")
                        narrator("You twist around to see nothing at all.")
                    elif choice2=='2':
                        print("\n")
                        narrator("You hear the sounds approach fast, then not a sound at all.")
                    else:
                        validop()
                player("(What is going on I feel like I am going insane. I swear I heard something...)")
                player("(I don't really know what to do now I feel like curling up in a ball but I feel like I should move from here I don't know what to do.)")
                while choice3 not in options:
                    optionsfunc("Hide until moring","Go somewhere else")
                    choice3=input()
                    if choice3=='1':
                        print("\n")
                        goodending()
                    elif choice3=='2':
                        print("\n")
                        wander()
                    else:
                        validop()
        
    
def fedup(): #this leads to alone()
    options=['1','2']
    choice1="" #Ask to turn around variable
    choice2=""#Ask what is wrong variable
    narrator("After a short amount of time of walking the sunlight starts to fade a little more")
    player("(I am thinking we should turn around should I ask Dylan if we can?)")
    while choice1 not in options:
        optionsfunc("Ask him","Say nothing")
        choice1=input()
        if choice1 =='1':#ask to turn around choice
            print("\n")
            player("Okay Dylan we are starting to not be able to see we should really head back especially on a path like this.")
            dylan("You worry so much I am suprised you haven't had a heart attack yet.")
            player("Dylan can we please turn around?")
            dylan("No don't change up your commitment after that little speech you gave")
            dylan("Its okay I can still get us back even if it is dark")
        elif choice1 =='2': #don't say anything
            print("\n")
            player("(You hold you tongue and put your faith in Dylan)")
        else:
            validop()
    narrator("As you continue further you notice Dylan is acting strange and seems to be worried")
    player("(Should I push and ask what is up with him?)")
    while choice2 not in options: #Ask what is wrong choice
        optionsfunc("Ask him","Don't say anything")
        choice2=input()
        if choice2 =='1':#Ask him what is wrong, goes to alone()
            print("\n")
            player("Dylan you look almost as pale as a ghost what is wrong")
            dylan("Promise that you wouldn't be mad at me.")
            player("I can make no such promise")
            dylan("I left the map in the truck....")
            if choice1 =='1': #changes dialogue if you ask him in choice1
                player("I JUST asked you if you knew what you were doing and you straight up lied to me.")
                dylan("I mean I kind of did tell a half truth.")
                player("Yeah whatever man I am done following you around I am turning around and heading back before you get us killed.")
                narrator("In your anger you turn around leaving Dylan behind.")
                alone()
            else: #changes dialogue to if you didn't ask him in choice1 
                player("Why would you not tell me something like that?")
                dylan("I already knew that you were pretty nervous and I didn't wanna add to it.")
                player("Yeah whatever man I am done following you around I am turning around and heading back before you get us killed.")
                narrator("In your anger you turn around leaving Dylan behind.")
                alone()
        elif choice2=='2': #Don't ask him what is wrong, goes to alone()
            print("\n")
            narrator("You stand and observe Dylan as he starts to act more and more frantic, after completely stopping Dylan approaches you with his head down." )
            dylan("Something is bothering me and I need to clear my conscience.")
            player("Oh really I couldn't tell.")
            dylan(f"Hey {name} this is serious okay.")
            player("Alright dude what is it?")
            dylan("I left the map in the truck...")
            if choice1=='1': #changes dialogue if you ask him in choice1
                player("I JUST asked you if you knew what you were doing and you straight up lied to me.")
                dylan("Look I know but I am coming to you now about it now so can't you trust me a little more?")
                player("Yeah whatever man I am done following you around I am turning around and heading back before you get us killed.")
                narrator("In your anger you turn around leaving Dylan behind.")
                alone()
            else: #changes dialogue to if you didn't ask him in choice1 
                player("Why would you wait until right now to tell me something like that?")
                dylan("I already knew that you were pretty nervous and I didn't wanna add to it.")
                player("Yeah whatever man I am done following you around I am turning around and heading back before you get us killed.")
                narrator("In your anger you turn around leaving Dylan behind.")
                alone()
        else:
            validop()
  
def trail(): #contains player choice for phone and leads to alone() and fedup()
    options=['1','2']
    choice1=""#grab phone choice variable
    choice2=""#leave dylan choice variable
    narrator(f"After some more light conversation you and Dylan hop into your 1982 evergreen GMC high sierra and head for the mountains. As you are driving the grey overtones from the clouds cause a dreary feeling to slowly creep over you.")
    player("I hope it doens't rain I can start to smell the rain in the sky")
    dylan("It'll be okay a litte rain shouldn't hurt us")
    player("I am not worried about the rain. The clouds make it hard to see how much daylight we have and daylight savings has been messing up my sense of time.")
    dylan("You worry to much man, please its not like we are in some horror movie we'll be fine")
    narrator("After some more time you and Dylan arrive to the trail")
    dylan("Hey man I was thinking that we should leave our phones it would add more to the nature experience.")
    player("(This guy can't be serious)")
    
    while choice1 not in options:#grab phone player choice
        optionsfunc("Grab phone","Leave phone")
        choice1=input()
        if choice1=='1':#grab phone
            print("\n")
            player("I already feel unsafe I am going to grab it anyways.")
            dylan("I truly don't know what I expected from the shut in")
            global phone.
            phone=True
        elif choice1=='2': #leave phone
            print("\n")
            player("You are right I might be able to get more immersed in the experience if I leave it.")
            dylan("Thank you for trusting in the process, I promise you wouldn't be disappointed")
        else:
            validop()
    narrator("You both begin to hike up the nature trail. The atmosphere is pleasent you can hear a few song birds softly playing their tunes. You both are walking by a river and you are watching the rocks hold strong against the gentle but firm tide of the river. As the group approaches a fork in the road Dylan decides that the group will go right. The orange and red autumn leafs slowly bleeding onto the path you walk starts to make your cautions lower.")
    narrator("Eventually the group reaches two signs that state.")
    Signs= "\nWalking path not maintained Users Assume all risks \n\nSTAY ON DESIGNATED TRAIL\n\n"
    print(Signs.upper()) #didn't want to retype so I just did this
    player("Hey Dylan I don't think we should keep going, it's getting kind of late and we WILL get lost")
    dylan("Hey remember what I said about living?")
    player("It seems that you have zero intention of living yourself")
    player("Seriously we are not going to be able to see the trail even with flashlights, lets just go.")
    dylan("That is fine if you want to be a buzz kill but I am not going to turn around because of some silly fear of the  DARK  .")
    #print(bool(phone==True)) Testing if the phone variable works as intented 
    while choice2 not in options: #leave dylan options
        optionsfunc("Leave Dylan and start going back to the truck","Continue with Dylan")
        choice2=input()
        if choice2=='1':#leave, goes to alone()
            print("\n")
            player("You know what Dylan I am done with you constantly dismissing how I feel and i'm out of here ill be waiting for you at the car")
            dylan("All find with me buckaroo")
            player("(Did he really just call me buckaroo?)")
            player("Have fun dying Dylan...")
            alone()
        elif choice2=='2':#Continues, Goes to fedup()
            print("\n")
            player("First I am not scared of the dark and second I think that you are an idiot but I am tired of getting permanitly dogged on by you so i'm willing to quote \"Live a little.\"")
            dylan("I knew you would come around eventually come on lets get right to it then since we have \"no time to lose.\"")
            fedup()
            
        else:
            validop()
        
def introscene(): #leads to trail()
    options=['1','2']
    choice="" #exposition option
    narrator("As fall break finally arrives you and your best friend Dylan are sitting in your dorm room.")
    dylan("Man what should we do for fall break?")
    player("I don't know ... I have a coding project due in my CS class and I just want to sleep.")
    dylan("And you wonder why you are always so lonely, live a little dude.")
    player(f"*{name} looks up* Bro really? Come on there are more important things in life, but what did you have in mind?")
    dylan("No need to be so dramatic, have you heard of the Appalachian Trial? I've heard some spooooky things about it.")
    player("(Dylan loves to play up up stories, should I hear him out?)")
   
    while choice not in options:#Allows player to pick where to go
        optionsfunc("Ask him to explain","Dismiss him")
        choice=input()
        if choice == '1': #Explaination, goes to trail()
            print("\n")
            player("I know literally nothing about the mountains, what did you hear?")
            dylan("Well it is one of the most immersive nature experiences out there so naturally there are a lot \nof missing people")
            player("I mean that makes sense to me")
            dylan("The more interesting things are that there are rumors of Bigfoot, Skinwalkers, Moth-Man, and inbreds who \nhave been hidden away from society for years")
            player("Please don't tell me you actually believe in those things")
            dylan("Remember what I said about being no fun? this is EXACTLY what I am talking about")
            player("You are making me not want to go more and more Dylan")
            dylan("I asked you if you wanted to hear and you said yes, I don't know why you are mad. Trust me just this once")
            player("okay I will go, don't make me regret this")
            trail()
        elif choice =='2': #Dismisses him, goes to trail()
            print("\n")
            player("Dylan I don't even know how to spell Appalachian so im definitely not interested in hearing \none of your tall tales about it")
            dylan("Okay thats fine I guess but are you going to come, i'll do anything you want")
            player("I guess I will, only if you get off my case a little")
            dylan("deal")
            trail()
        else:
            validop()
def main():#leads to introscene()
    global phone
    phone=False #If replaying the game makes sure to reset this option so it doesn't mess any choices up
    print("Hello welcome to our text based adventure game :)")
    global name
    name=""
    check=""
    while check in name: #to check if player actually entered in a name
        name=input("\nWhat is your name?: ").title()
        if name == check:
            print("\nPlease enter a name")
        else:
            break
    
    disclamer=print("\nThis is a horror game that contains mature themes. \nIf you cannot handle this than I recommend you DO NOT play this game.\nView discretion is advised")
    print("\nGood Luck "+name+".\n\n")
    introscene()
    
    

if __name__ == "__main__":
    main()
# Out:
# Hello welcome to our text based adventure game :)
#
# What is your name?: joe
#
# This is a horror game that contains mature themes.
# If you cannot handle this than I recommend you DO NOT play this game.
# View discretion is advised
#
# Good Luck Joe.
#
#
# As fall break finally arrives you and your best friend Dylan are sitting in your
# dorm room.
#
# Dylan: Man what should we do for fall break?
#
# Joe: I don't know ... I have a coding project due in my CS class and I just want to
# sleep
#
# Dylan: This is why you have no friends and you phone is dry all the time, live a little
# dude
#
# Joe: *Joe looks up* Bro really? Come on there are more important things in life, but
# what did you have in mind?
#
# Dylan: No need to be so dramatic, have you heard of the Appalachian Trial? I've heard
# some spooooky things about it
#
# Joe: (Dylan loves to play up up stories, should I hear him out?)
#
#
# 1. Ask him to explain
# 2. Dismiss him
#
# Enter Option (1/2)
# 1
#
#
# ...
